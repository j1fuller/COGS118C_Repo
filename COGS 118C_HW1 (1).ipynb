# %% [markdown]
# # Cogs 118C
#
#
# ## HW1

# %% [markdown]
# Name: Jonathan Fuller
#
# Student ID: A17026410

# %% [markdown]
# ## Q2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create time vector
t = np.linspace(0, 10, 1000)  # 1000 points between 0 and 10s
T = 2  # For function 5

# Create figure with subplots
plt.figure(figsize=(15, 25))

# a. f(t) = 3sin(3t) - 2
plt.subplot(7, 1, 1)
y1 = 3 * np.sin(3*t) - 2
plt.plot(t, y1)
plt.title('f(t) = 3sin(3t) - 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# b. f(t) = (t-5)^2 + 2
plt.subplot(7, 1, 2)
y2 = (t - 5)**2 + 2
plt.plot(t, y2)
plt.title('f(t) = (t-5)^2 + 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# c. f(t) = cos^3(2πt/√3)
plt.subplot(7, 1, 3)
y3 = np.cos(2*np.pi*t/np.sqrt(3))**3
plt.plot(t, y3)
plt.title('f(t) = cos^3(2πt/√3)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# d. f(t) = exp[-sin^2(3πt)]
plt.subplot(7, 1, 4)
y4 = np.exp(-np.sin(3*np.pi*t)**2)
plt.plot(t, y4)
plt.title('f(t) = exp[-sin^2(3πt)]')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# e. f(t) = sin([t/T]+1.3) + cos(5t/T)
plt.subplot(7, 1, 5)
y5 = np.sin(t/T + 1.3) + np.cos(5*t/T)
plt.plot(t, y5)
plt.title('f(t) = sin([t/T]+1.3) + cos(5t/T), T=2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# f. f(t) = sin(1/t)
plt.subplot(7, 1, 6)
# Avoid division by zero by starting t slightly above 0
t_modified = np.linspace(0.1, 10, 1000)
y6 = np.sin(1/t_modified)
plt.plot(t_modified, y6)
plt.title('f(t) = sin(1/t)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# g. Sum series f(t) = Σ(1/n)*sin(nt), n=1 to N=100
plt.subplot(7, 1, 7)
y7 = np.zeros_like(t)
N = 100
for n in range(1, N+1):
    y7 += (1/n) * np.sin(n*t)
plt.plot(t, y7)
plt.title('f(t) = Σ(1/n)*sin(nt), N=100')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

plt.tight_layout()

# %% [markdown]
# ## Q3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 0.005  # Amplitude in microvolts
f = 5      # Frequency in Hz
t = np.linspace(0, 1, 1000)  # Time vector from 0 to 1 second, 1000 points

# Calculate LFP signal
f1 = A * np.sin(2 * np.pi * f * t)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(t, f1)

# Add labels and title
plt.xlabel('Time (s)')
plt.ylabel('LFP Amplitude (µV)')
plt.title('Single Neuron LFP Response')

# Add grid for better readability
plt.grid(True)

# Ensure tight layout
plt.tight_layout()

# %% [markdown]
# ### pt. e

# %% [markdown]
# $SNR_{dB} = 20 \log_{10}(\frac{Signal_{RMS}}{Noise_{RMS}})$
# $SNR_{dB} = 20 \log_{10}(\frac{0.00791 \sqrt{n}}{10})$
# $SNR_{dB} = 20 \log_{10}(0.000791 \sqrt{n})$
# $SNR_{dB} = 20 [\log_{10}(0.000791) + \log_{10}(\sqrt{n})]$
# $SNR_{dB} = 20 [-3.10 + 0.5 \log_{10}(n)]$

# %% [markdown]
# ### Q5

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# %%
# Load audio file. This code will read the wav file
Fs, aud = wavfile.read('HW1_audio.wav')

# %%
# The audio file has two channels (stereo - Left and Right). 
# For simplicity, we will keep just one channel.
aud = aud[:,0]

# %%
# (a) What are the sampling rate and duration (in s) of the recording?
duration = len(aud) / Fs
print(f"Sampling rate (Fs): {Fs} Hz")
print(f"Duration: {duration:.2f} seconds")
# Out:
# Sampling rate (Fs): 48000 Hz
# Duration: 13.30 seconds

# %%
# (b) Make a plot showing the first 1.5 s of the recording.
# Label the axes (x axis: Time (s), y-axis: Sound pressure).
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# Load audio file
Fs, aud = wavfile.read('HW1_audio.wav')
aud = aud[:,0]  # Keep just one channel

# Create time vector for first 1.5 seconds
duration = 1.5  # seconds to plot
n_samples = int(Fs * duration)  # number of samples for 1.5s
t = np.linspace(0, duration, n_samples)

# Plot the first 1.5s
plt.figure(figsize=(12, 6))
plt.plot(t, aud[:n_samples])

# Add labels and title
plt.xlabel('Time (s)')
plt.ylabel('Sound Pressure')
plt.title('First 1.5 Seconds of Audio Recording')

# Add grid for better readability
plt.grid(True)

# Ensure proper layout
plt.tight_layout()

# %%
# (c) Downsample the recording by a factor of 15, i.e. select every 15th
# sample of the recorded signal and throw away the rest. Hint: you can 
# do this using numpy array "slicing" (https://docs.scipy.org/doc/numpy/reference/arrays.indexing.html):

# The basic slice syntax is i:j:k where i is the starting index, j is the stopping index, 
# and k is the step (k ≠ 0). This selects the m elements (in the corresponding dimension)
# with index values i, i + k, …, i + (m - 1) k where m = q + (r\neq0) and q and r are the 
# quotient and remainder obtained by dividing j - i by k: j - i = q k + r, so that 
# i + (m - 1) k < j.

# For example, the syntax x[0:10:2] would select every 2nd element of x starting with 
# the first (0) and ending with the 10th. 

# Another example: x[::2] would give every 2nd element of x, starting with 0 and ending with 
# the last element of x. In this case, the "missing" values of i and j are automatically
# interpreted as the first and last elements

# What is the new sampling rate, Fs_dsamp?
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# Load audio file
Fs, aud = wavfile.read('HW1_audio.wav')
aud = aud[:,0]  # Keep just one channel

# Downsample by factor of 15 using array slicing
aud_dsamp = aud[::15]

# Calculate new sampling rate
Fs_dsamp = Fs/15

print(f"Original sampling rate: {Fs} Hz")
print(f"Downsampled sampling rate (Fs_dsamp): {Fs_dsamp} Hz")

# Verify the length reduction
print(f"Original number of samples: {len(aud)}")
print(f"Downsampled number of samples: {len(aud_dsamp)}")
# Out:
# Original sampling rate: 48000 Hz
# Downsampled sampling rate (Fs_dsamp): 3200.0 Hz
# Original number of samples: 638632
# Downsampled number of samples: 42576

# %%
#(d)
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# Load audio file
Fs, aud = wavfile.read('HW1_audio.wav')
aud = aud[:,0]  # Keep just one channel

# Downsample
aud_dsamp = aud[::15]
Fs_dsamp = Fs/15

# Create time vectors for first 1.5 seconds
t_orig = np.linspace(0, 1.5, int(Fs * 1.5))
t_dsamp = np.linspace(0, 1.5, int(Fs_dsamp * 1.5))

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Plot original signal
ax1.plot(t_orig, aud[:len(t_orig)], 'b-', label='Original')
ax1.set_title('Original Signal (Fs = 48000 Hz)')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Sound Pressure')
ax1.grid(True)

# Plot downsampled signal
ax2.plot(t_dsamp, aud_dsamp[:len(t_dsamp)], 'r-', label='Downsampled')
ax2.set_title('Downsampled Signal (Fs = 3200 Hz)')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Sound Pressure')
ax2.grid(True)

# Adjust layout
plt.tight_layout()

# %%
# (e) Save the audio file
import numpy as np
import scipy.io.wavfile as wavfile

# Load original audio
Fs, aud = wavfile.read('HW1_audio.wav')
aud = aud[:,0]  # Keep just one channel

# Downsample
aud_dsamp = aud[::15]  # Take every 15th sample

# Save downsampled audio using the provided code structure
wavfile.write('HW1_dsamp.wav', int(Fs/15), aud_dsamp)
